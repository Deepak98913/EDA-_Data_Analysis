# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


import warnings
warnings.filterwarnings('ignore')

plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option('display.max_columns', 30)

# %%
df = pd.read_csv("us_perm_visas.csv")

# %%
df
# Out:
#       add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# 0                             NaN         NaN              NaN          NaN
# 1                             NaN         NaN              NaN          NaN
# 2                             NaN         NaN              NaN          NaN
# 3                             NaN         NaN              NaN          NaN
# 4                             NaN         NaN              NaN          NaN
# ...                           ...         ...              ...          ...
# 9598                          NaN         NaN              NaN          NaN
# 9599                          NaN         NaN              NaN          NaN
# 9600                          NaN         NaN              NaN          NaN
# 9601                          NaN         NaN              NaN          NaN
# 9602                          NaN         NaN              NaN          NaN
#
#      application_type        case_no  case_number  case_received_date  \
# 0                PERM  A-07323-97014          NaN                 NaN
# 1                PERM  A-07332-99439          NaN                 NaN
# 2                PERM  A-07333-99643          NaN                 NaN
# 3                PERM  A-07339-01930          NaN                 NaN
# 4                PERM  A-07345-03565          NaN                 NaN
# ...               ...            ...          ...                 ...
# 9598             PERM  A-11218-98019          NaN                 NaN
# 9599             PERM  A-11218-98020          NaN                 NaN
# 9600             PERM  A-11218-98021          NaN                 NaN
# 9601             PERM  A-11219-98024          NaN                 NaN
# 9602             PERM  A-11219-98026          NaN                 NaN
#
#             case_status class_of_admission  country_of_citizenship  \
# 0             Certified                J-1                     NaN
# 1                Denied                B-2                     NaN
# 2             Certified               H-1B                     NaN
# 3             Certified                B-2                     NaN
# 4             Certified                L-1                     NaN
# ...                 ...                ...                     ...
# 9598          Certified               H-1B                     NaN
# 9599  Certified-Expired               H-1B                     NaN
# 9600  Certified-Expired               H-1B                     NaN
# 9601  Certified-Expired               H-1B                     NaN
# 9602  Certified-Expired               H-1B                     NaN
#
#      country_of_citzenship decision_date          employer_address_1  \
# 0                  ARMENIA    2012-02-01           24 WEST 25 STREET
# 1                   POLAND    2011-12-21            200 BROAD STREET
# 2                    INDIA    2011-12-01  1054 TECHNOLOGY PARK DRIVE
# 3              SOUTH KOREA    2011-12-01     33-17 PRINCE ST. 2ND FL
# 4                   CANADA    2012-01-26               1373 BROADWAY
# ...                    ...           ...                         ...
# 9598                 INDIA    2011-11-07       230 PARK AVENUE SOUTH
# 9599                POLAND    2011-10-25              7 WILLITS ROAD
# 9600           SOUTH KOREA    2011-10-26       2570 PLEASANT HILL RD
# 9601                  PERU    2011-10-25    7500 OLD GEORGETOWN ROAD
# 9602            BANGLADESH    2011-10-19               GATEWAY TOWER
#
#                 employer_address_2  ... ri_layoff_in_past_six_months  \
# 0                        5TH FLOOR  ...                          NaN
# 1                              NaN  ...                          NaN
# 2                              NaN  ...                          NaN
# 3                              NaN  ...                          NaN
# 4                              NaN  ...                          NaN
# ...                            ...  ...                          ...
# 9598                     8TH FLOOR  ...                          NaN
# 9599                           NaN  ...                          NaN
# 9600                       STE 107  ...                          NaN
# 9601                     SUITE 800  ...                          NaN
# 9602  8111 LBJ FREEWAY, SUITE 1250  ...                          NaN
#
#       ri_local_ethnic_paper_from  ri_local_ethnic_paper_to  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 9598                         NaN                       NaN
# 9599                         NaN                       NaN
# 9600                         NaN                       NaN
# 9601                         NaN                       NaN
# 9602                         NaN                       NaN
#
#      ri_posted_notice_at_worksite  ri_pvt_employment_firm_from  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 9598                          NaN                          NaN
# 9599                          NaN                          NaN
# 9600                          NaN                          NaN
# 9601                          NaN                          NaN
# 9602                          NaN                          NaN
#
#       ri_pvt_employment_firm_to  ri_us_workers_considered  schd_a_sheepherder  \
# 0                           NaN                       NaN                 NaN
# 1                           NaN                       NaN                 NaN
# 2                           NaN                       NaN                 NaN
# 3                           NaN                       NaN                 NaN
# 4                           NaN                       NaN                 NaN
# ...                         ...                       ...                 ...
# 9598                        NaN                       NaN                 NaN
# 9599                        NaN                       NaN                 NaN
# 9600                        NaN                       NaN                 NaN
# 9601                        NaN                       NaN                 NaN
# 9602                        NaN                       NaN                 NaN
#
#          us_economic_sector  wage_offer_from_9089  wage_offer_to_9089  \
# 0                        IT              75629.00                 NaN
# 1     Other Economic Sector              37024.00                 NaN
# 2                 Aerospace              47923.00                 NaN
# 3     Other Economic Sector                 10.97                 NaN
# 4              Advanced Mfg             100000.00                 NaN
# ...                     ...                   ...                 ...
# 9598  Other Economic Sector              84885.00                 NaN
# 9599           Construction             171600.00                 NaN
# 9600                    NaN              42000.00                 NaN
# 9601                     IT              60000.00             80000.0
# 9602                    NaN                   NaN                 NaN
#
#       wage_offer_unit_of_pay_9089  wage_offered_from_9089  \
# 0                              yr                     NaN
# 1                              yr                     NaN
# 2                              yr                     NaN
# 3                              hr                     NaN
# 4                              yr                     NaN
# ...                           ...                     ...
# 9598                           yr                     NaN
# 9599                           yr                     NaN
# 9600                           yr                     NaN
# 9601                           yr                     NaN
# 9602                          NaN                     NaN
#
#       wage_offered_to_9089  wage_offered_unit_of_pay_9089
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
# 3                      NaN                            NaN
# 4                      NaN                            NaN
# ...                    ...                            ...
# 9598                   NaN                            NaN
# 9599                   NaN                            NaN
# 9600                   NaN                            NaN
# 9601                   NaN                            NaN
# 9602                   NaN                            NaN
#
# [9603 rows x 154 columns]

# %%
df['case_no']
# Out:
# 0       A-07323-97014
# 1       A-07332-99439
# 2       A-07333-99643
# 3       A-07339-01930
# 4       A-07345-03565
#             ...
# 9598    A-11218-98019
# 9599    A-11218-98020
# 9600    A-11218-98021
# 9601    A-11219-98024
# 9602    A-11219-98026
# Name: case_no, Length: 9603, dtype: object

# %%
df.drop("case_no", axis = 1, inplace = True)

# %%
df
# Out:
#       add_these_pw_job_title_9089  agent_city  agent_firm_name  agent_state  \
# 0                             NaN         NaN              NaN          NaN
# 1                             NaN         NaN              NaN          NaN
# 2                             NaN         NaN              NaN          NaN
# 3                             NaN         NaN              NaN          NaN
# 4                             NaN         NaN              NaN          NaN
# ...                           ...         ...              ...          ...
# 9598                          NaN         NaN              NaN          NaN
# 9599                          NaN         NaN              NaN          NaN
# 9600                          NaN         NaN              NaN          NaN
# 9601                          NaN         NaN              NaN          NaN
# 9602                          NaN         NaN              NaN          NaN
#
#      application_type  case_number  case_received_date        case_status  \
# 0                PERM          NaN                 NaN          Certified
# 1                PERM          NaN                 NaN             Denied
# 2                PERM          NaN                 NaN          Certified
# 3                PERM          NaN                 NaN          Certified
# 4                PERM          NaN                 NaN          Certified
# ...               ...          ...                 ...                ...
# 9598             PERM          NaN                 NaN          Certified
# 9599             PERM          NaN                 NaN  Certified-Expired
# 9600             PERM          NaN                 NaN  Certified-Expired
# 9601             PERM          NaN                 NaN  Certified-Expired
# 9602             PERM          NaN                 NaN  Certified-Expired
#
#      class_of_admission  country_of_citizenship country_of_citzenship  \
# 0                   J-1                     NaN               ARMENIA
# 1                   B-2                     NaN                POLAND
# 2                  H-1B                     NaN                 INDIA
# 3                   B-2                     NaN           SOUTH KOREA
# 4                   L-1                     NaN                CANADA
# ...                 ...                     ...                   ...
# 9598               H-1B                     NaN                 INDIA
# 9599               H-1B                     NaN                POLAND
# 9600               H-1B                     NaN           SOUTH KOREA
# 9601               H-1B                     NaN                  PERU
# 9602               H-1B                     NaN            BANGLADESH
#
#      decision_date          employer_address_1            employer_address_2  \
# 0       2012-02-01           24 WEST 25 STREET                     5TH FLOOR
# 1       2011-12-21            200 BROAD STREET                           NaN
# 2       2011-12-01  1054 TECHNOLOGY PARK DRIVE                           NaN
# 3       2011-12-01     33-17 PRINCE ST. 2ND FL                           NaN
# 4       2012-01-26               1373 BROADWAY                           NaN
# ...            ...                         ...                           ...
# 9598    2011-11-07       230 PARK AVENUE SOUTH                     8TH FLOOR
# 9599    2011-10-25              7 WILLITS ROAD                           NaN
# 9600    2011-10-26       2570 PLEASANT HILL RD                       STE 107
# 9601    2011-10-25    7500 OLD GEORGETOWN ROAD                     SUITE 800
# 9602    2011-10-19               GATEWAY TOWER  8111 LBJ FREEWAY, SUITE 1250
#
#      employer_city  ...  ri_layoff_in_past_six_months  \
# 0         NEW YORK  ...                           NaN
# 1        CARLSTADT  ...                           NaN
# 2       GLEN ALLEN  ...                           NaN
# 3         FLUSHING  ...                           NaN
# 4           ALBANY  ...                           NaN
# ...            ...  ...                           ...
# 9598      NEW YORK  ...                           NaN
# 9599     GLEN COVE  ...                           NaN
# 9600        DULUTH  ...                           NaN
# 9601      BETHESDA  ...                           NaN
# 9602        DALLAS  ...                           NaN
#
#       ri_local_ethnic_paper_from ri_local_ethnic_paper_to  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
# ...                          ...                      ...
# 9598                         NaN                      NaN
# 9599                         NaN                      NaN
# 9600                         NaN                      NaN
# 9601                         NaN                      NaN
# 9602                         NaN                      NaN
#
#       ri_posted_notice_at_worksite  ri_pvt_employment_firm_from  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 9598                           NaN                          NaN
# 9599                           NaN                          NaN
# 9600                           NaN                          NaN
# 9601                           NaN                          NaN
# 9602                           NaN                          NaN
#
#       ri_pvt_employment_firm_to  ri_us_workers_considered schd_a_sheepherder  \
# 0                           NaN                       NaN                NaN
# 1                           NaN                       NaN                NaN
# 2                           NaN                       NaN                NaN
# 3                           NaN                       NaN                NaN
# 4                           NaN                       NaN                NaN
# ...                         ...                       ...                ...
# 9598                        NaN                       NaN                NaN
# 9599                        NaN                       NaN                NaN
# 9600                        NaN                       NaN                NaN
# 9601                        NaN                       NaN                NaN
# 9602                        NaN                       NaN                NaN
#
#          us_economic_sector  wage_offer_from_9089  wage_offer_to_9089  \
# 0                        IT              75629.00                 NaN
# 1     Other Economic Sector              37024.00                 NaN
# 2                 Aerospace              47923.00                 NaN
# 3     Other Economic Sector                 10.97                 NaN
# 4              Advanced Mfg             100000.00                 NaN
# ...                     ...                   ...                 ...
# 9598  Other Economic Sector              84885.00                 NaN
# 9599           Construction             171600.00                 NaN
# 9600                    NaN              42000.00                 NaN
# 9601                     IT              60000.00             80000.0
# 9602                    NaN                   NaN                 NaN
#
#       wage_offer_unit_of_pay_9089  wage_offered_from_9089  \
# 0                              yr                     NaN
# 1                              yr                     NaN
# 2                              yr                     NaN
# 3                              hr                     NaN
# 4                              yr                     NaN
# ...                           ...                     ...
# 9598                           yr                     NaN
# 9599                           yr                     NaN
# 9600                           yr                     NaN
# 9601                           yr                     NaN
# 9602                          NaN                     NaN
#
#       wage_offered_to_9089  wage_offered_unit_of_pay_9089
# 0                      NaN                            NaN
# 1                      NaN                            NaN
# 2                      NaN                            NaN
# 3                      NaN                            NaN
# 4                      NaN                            NaN
# ...                    ...                            ...
# 9598                   NaN                            NaN
# 9599                   NaN                            NaN
# 9600                   NaN                            NaN
# 9601                   NaN                            NaN
# 9602                   NaN                            NaN
#
# [9603 rows x 153 columns]

# %%
df.case_status
# Out:
# 0               Certified
# 1                  Denied
# 2               Certified
# 3               Certified
# 4               Certified
#               ...
# 9598            Certified
# 9599    Certified-Expired
# 9600    Certified-Expired
# 9601    Certified-Expired
# 9602    Certified-Expired
# Name: case_status, Length: 9603, dtype: object

# %%
df = df[df["case_status"] != "Withdrawn"]

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'Certified-Expired'], dtype=object)

# %%
df.loc[df.case_status == 'Certified-Expired', 'case_status'] = 'Certified'

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied'], dtype=object)

# %%
df.case_status.value_counts()
# Out:
# Certified    7454
# Denied       1841
# Name: case_status, dtype: int64

# %%
# insights >>
1841 / 7454
# Out:
# 0.24698148645022808

# %%
df.case_status.value_counts(normalize = True)
# Out:
# Certified    0.801937
# Denied       0.198063
# Name: case_status, dtype: float64

# %%
df.dropna(axis = 1, how = 'all', inplace = True)

# %%
df.shape
# Out:
# (9295, 26)

# %%
df.columns
# Out:
# Index(['application_type', 'case_status', 'class_of_admission',
#        'country_of_citzenship', 'decision_date', 'employer_address_1',
#        'employer_address_2', 'employer_city', 'employer_name',
#        'employer_postal_code', 'employer_state', 'job_info_work_city',
#        'job_info_work_state', 'naics_2007_us_code', 'naics_2007_us_title',
#        'pw_amount_9089', 'pw_job_title_9089', 'pw_level_9089', 'pw_soc_code',
#        'pw_soc_title', 'pw_source_name_9089', 'pw_unit_of_pay_9089',
#        'us_economic_sector', 'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089'],
#       dtype='object')

# %%
df.application_type
# Out:
# 0       PERM
# 1       PERM
# 2       PERM
# 3       PERM
# 4       PERM
#         ...
# 9598    PERM
# 9599    PERM
# 9600    PERM
# 9601    PERM
# 9602    PERM
# Name: application_type, Length: 9295, dtype: object

# %%
df['application_type'].value_counts().plot(kind = 'bar', color = 'red')
# Out:
# <Axes: >

# %%
# most people online

# %%
sns.countplot(data = df, x='application_type')
# Out:
# <Axes: xlabel='application_type', ylabel='count'>

# %%
df.columns
# Out:
# Index(['application_type', 'case_status', 'class_of_admission',
#        'country_of_citzenship', 'decision_date', 'employer_address_1',
#        'employer_address_2', 'employer_city', 'employer_name',
#        'employer_postal_code', 'employer_state', 'job_info_work_city',
#        'job_info_work_state', 'naics_2007_us_code', 'naics_2007_us_title',
#        'pw_amount_9089', 'pw_job_title_9089', 'pw_level_9089', 'pw_soc_code',
#        'pw_soc_title', 'pw_source_name_9089', 'pw_unit_of_pay_9089',
#        'us_economic_sector', 'wage_offer_from_9089', 'wage_offer_to_9089',
#        'wage_offer_unit_of_pay_9089'],
#       dtype='object')

# %%
df.us_economic_sector
# Out:
# 0                          IT
# 1       Other Economic Sector
# 2                   Aerospace
# 3       Other Economic Sector
# 4                Advanced Mfg
#                 ...
# 9598    Other Economic Sector
# 9599             Construction
# 9600                      NaN
# 9601                       IT
# 9602                      NaN
# Name: us_economic_sector, Length: 9295, dtype: object

# %%
economic_sector = df['us_economic_sector'].value_counts()

# %%
economic_sector
# Out:
# IT                       3198
# Other Economic Sector    1350
# Advanced Mfg             1234
# Educational Services      747
# Finance                   567
# Health Care               509
# Hospitality               351
# Retail                    319
# Aerospace                 267
# Construction              207
# Automotive                 94
# Transportation             79
# Energy                     64
# Agribusiness               52
# Biotechnology              26
# Homeland Security           6
# Geospatial                  6
# Name: us_economic_sector, dtype: int64

# %%
plt.figure(figsize=(10,10))
plt.pie(economic_sector, labels = economic_sector.index, autopct = '%1.1f%%')
plt.show()

# %%
# yow will get visa IT

# %%
df['decision_date']= pd.to_datetime(df['decision_date'])
df['year'] = df['decision_date'].dt.year

# %%
df['year']
# Out:
# 0       2012
# 1       2011
# 2       2011
# 3       2011
# 4       2012
#         ...
# 9598    2011
# 9599    2011
# 9600    2011
# 9601    2011
# 9602    2011
# Name: year, Length: 9295, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.countplot(x = 'year', hue = 'case_status', data = df)
ax.set(xlabel = "Visa_application_year", ylabel = "No of applications")
plt.show()

# %%
# insights as application increase, denied and accepted both increasing

# %%
fig, ax = plt.subplots(figsize = (8,8))
sns.countplot(x = 'employer_city', hue = 'year', data = df, order = df.employer_city.value_counts().iloc[:10].index)
ax.set(xlabel = "Visa_application_year", ylabel = "No of applications")
plt.xticks(rotation = 45)
plt.show()
