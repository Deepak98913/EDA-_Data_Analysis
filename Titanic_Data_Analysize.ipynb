# %%
import pandas as pd
import numpy as np

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests 
data  = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
df = data.json()

# %%
len(df)
# Out:
# 30

# %%
for i in range(len(df)):
    print(df[i]['user']['node_id'])
# Out:
# U_kgDOCVipDQ
# MDQ6VXNlcjQ0NTAwODg4
# MDQ6VXNlcjE0MDc1OTIy
# U_kgDOB6cYqg
# MDQ6VXNlcjIyMTIwMzg0
# MDQ6VXNlcjQ0NTAwODg4
# MDQ6VXNlcjYwNjIwNjA2
# MDQ6VXNlcjI0MjI3ODM4
# MDQ6VXNlcjI0MjI3ODM4
# MDQ6VXNlcjQ3OTYzMjE1
# MDQ6VXNlcjk3MjUyOTY=
# U_kgDOB5xixA
# MDQ6VXNlcjUyNzkyOTk5
# MDQ6VXNlcjgwNzg5Njg=
# U_kgDOB2aEBg
# MDQ6VXNlcjQ3OTYzMjE1
# MDQ6VXNlcjE0MDc1OTIy
# MDQ6VXNlcjQ1NTYyNDAy
# U_kgDOByhD2w
# MDQ6VXNlcjkxMTYwNDc1
# MDQ6VXNlcjI1NDY1NDM=
# MDQ6VXNlcjUyNzkyOTk5
# MDQ6VXNlcjM5NTA0MjMz
# MDQ6VXNlcjUyNzkyOTk5
# MDQ6VXNlcjY1NjI1MzQ4
# MDQ6VXNlcjE4MTM1MzQ4
# MDQ6VXNlcjYwNjA5ODc5
# MDQ6VXNlcjEwMjA0OTY=
# U_kgDOCduQxA
# MDQ6VXNlcjEzMDQ5NTA=

# %%
df = pd.DataFrame(df, columns = ['user','timeline_url'])

# %%
df.to_csv('json_info.csv')

# %%
df
# Out:
#                                                  user  \
# 0   {'login': 'v-lozko', 'id': 156805389, 'node_id...
# 1   {'login': 'bergnerjonas', 'id': 44500888, 'nod...
# 2   {'login': 'neutrinoceros', 'id': 14075922, 'no...
# 3   {'login': 'DuarteMarques510', 'id': 128391338,...
# 4   {'login': 'AlanCPSC', 'id': 22120384, 'node_id...
# 5   {'login': 'bergnerjonas', 'id': 44500888, 'nod...
# 6   {'login': 'kamelCased', 'id': 60620606, 'node_...
# 7   {'login': 'Tonow', 'id': 24227838, 'node_id': ...
# 8   {'login': 'Tonow', 'id': 24227838, 'node_id': ...
# 9   {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 10  {'login': 'benHeid', 'id': 9725296, 'node_id':...
# 11  {'login': 'lamprinikourou', 'id': 127689412, '...
# 12  {'login': 'Aloqeely', 'id': 52792999, 'node_id...
# 13  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 14  {'login': 'rob-sil', 'id': 124158982, 'node_id...
# 15  {'login': 'lithomas1', 'id': 47963215, 'node_i...
# ...

# %%
# Solving the dataset

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe() #numerical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId', 'Survived', 'Pclass']]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes == 'objects'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes != 'object'].index].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe(include = 'object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.astype('object').describe()
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare    Cabin Embarked
# count     891    891     891  891.00      204      889
# unique      7      7     681  248.00      147        3
# top         0      0  347082    8.05  B96 B98        S
# freq      608    678       7   43.00        4      644

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[10:100:3]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 13           14         0       3
# 16           17         0       3
# 19           20         1       3
# 22           23         1       3
# 25           26         1       3
# 28           29         1       3
# 31           32         1       1
# 34           35         0       1
# 37           38         0       3
# 40           41         0       3
# 43           44         1       2
# 46           47         0       3
# 49           50         0       3
# 52           53         1       1
# 55           56         1       1
# 58           59         1       2
# 61           62         1       1
# 64           65         0       1
# 67           68         0       3
# 70           71         0       2
# 73           74         0       3
# 76           77         0       3
# 79           80         1       3
# 82           83         1       3
# 85           86         1       3
# ...

# %%
df['new_col'] = "Deepak"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['family'] = df['SibSp'] + df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Q. How many passengers are less than 5 years old

df[df['Age'] < 5]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# ...

# %%
len(df[df['Age'] < 5])
# Out:
# 40

# %%
# no of passenger > 18
len(df[df['Age'] > 18])
# Out:
# 575

# %%
# how many passenger are less than or equal to 18 yers old

len(df[df['Age'] <= 18])
# Out:
# 139

# %%
# Q. How many passengers havve paid less than avg. fare

df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df[df['Fare'] <df['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
len(df[df['Fare'] <df['Fare'].mean()])
# Out:
# 680

# %%
df[df['Fare'] >df['Fare'].mean()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Fare'] >df['Fare'].mean()])
# Out:
# 211

# %%
# How many passengers pair 0 fare with name
df[df['Fare'] == 0].Name
# Out:
# 179                 Leonard, Mr. Lionel
# 263               Harrison, Mr. William
# 271        Tornquist, Mr. William Henry
# 277         Parkes, Mr. Francis "Frank"
# 302     Johnson, Mr. William Cahoone Jr
# 413      Cunningham, Mr. Alfred Fleming
# 466               Campbell, Mr. William
# 481    Frost, Mr. Anthony Wood "Archie"
# 597                 Johnson, Mr. Alfred
# 633       Parr, Mr. William Henry Marsh
# 674          Watson, Mr. Ennis Hastings
# 732                Knight, Mr. Robert J
# 806              Andrews, Mr. Thomas Jr
# 815                    Fry, Mr. Richard
# 822     Reuchlin, Jonkheer. John George
# Name: Name, dtype: object

# %%
len(df[df['Fare'] == 0])
# Out:
# 15

# %%
# how many males and females
df[df['Sex'] == "male"]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_col  \
# ...

# %%
len(df[df['Sex'] == "male"])
# Out:
# 577

# %%
df[df['Sex'] == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df['Sex'] == "female"])
# Out:
# 314

# %%
df['Sex'].value_counts(normalize = True)
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
# How many passengers of class 1
df[df['Pclass'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# How many passengers survived
df[df['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Survived'].value_counts(normalize = True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
# How many females paid more than avg. fare

df['Sex'] == 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df[(df['Sex'] == 'female') & (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# How many passengers are male or sho paid greater than avg fare >> or condition
# males passenger paid more than avg >> and condition.

df[(df['Sex'] == 'male') | (df['Fare'] > df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
np.mean(df['Fare'])
# Out:
# 32.204207968574636

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
min(df['Fare'])
# Out:
# 0.0

# %%
# Who are the passangers who paid maximun fare
df[df['Fare'] == max(df['Fare'])] ['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# How many passenger have parch greather than 3 
# how many passengers who survived paid maximum fare
# how many passengers who didn;t survived was from class 1
# how many passengers are having children( < 5 years old)

# %%
# Access df rows  # implicit index>internal index and explicit index>>you define 
df[0:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
df.iloc[0:2] # start from 0 and go to 1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked new_col  family
# 0      0  A/5 21171   7.2500   NaN        S  Deepak       1
# 1      0   PC 17599  71.2833   C85        C  Deepak       1

# %%
df.loc[0:2] # give me the rows whose name is 0 , 1, 2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col  family
# 0      0         A/5 21171   7.2500   NaN        S  Deepak       1
# 1      0          PC 17599  71.2833   C85        C  Deepak       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Deepak       0

# %%
df.loc[0:2,['Name', 'Sex', 'Age']]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0

# %%
df.iloc[0:2, 3:5]
# Out:
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female

# %%
df.iloc[0:2, [3,4,5]]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
df['Name'][2:14]
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# Name: Name, dtype: object

# %%
len(df['Name'][2:14])
# Out:
# 12

# %%
list(df['Name'][2:5])
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
s = pd.Series(list(df['Name'][2:5]), index = ['a','b','c'])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1 = pd.Series(list(df['Name'][5:8]), index = ['a','b','c'])

# %%
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s + s1 # Series or dataframe doesn't work with +
# Out:
# a               Heikkinen, Miss. LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master. Gosta...
# dtype: object

# %%
s.append(s1)
# Out:
# /tmp/ipykernel_111/137217768.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(s1)
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# a                                Moran, Mr. James
# b                         McCarthy, Mr. Timothy J
# c                  Palsson, Master. Gosta Leonard
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId', axis = 1,inplace = True) # row >>axis = 0, axis = 1 >> columns

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.drop(1,inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df.set_index('Name')
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss. Laina                               1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Allen, Mr. William Henry                             0       3    male  35.0
# Moran, Mr. James                                     0       3    male   NaN
# ...                                                ...     ...     ...   ...
# Montvila, Rev. Juozas                                0       2    male  27.0
# Graham, Miss. Margaret Edith                         1       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"             0       3  female   NaN
# Behr, Mr. Karl Howell                                1       1    male  26.0
# Dooley, Mr. Patrick                                  0       3    male  32.0
#
# ...

# %%
df.iloc[3]
# Out:
# Survived                           0
# Pclass                             3
# Name        Allen, Mr. William Henry
# Sex                             male
# Age                             35.0
# SibSp                              0
# Parch                              0
# Ticket                        373450
# Fare                            8.05
# Cabin                            NaN
# Embarked                           S
# new_col                       Deepak
# family                             0
# Name: 4, dtype: object

# %%
df.head()
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 0         0       3                       Braund, Mr. Owen Harris    male
# 2         1       3                        Heikkinen, Miss. Laina  female
# 3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         0       3                      Allen, Mr. William Henry    male
# 5         0       3                              Moran, Mr. James    male
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked new_col  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S  Deepak
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Deepak
# 3  35.0      1      0            113803  53.1000  C123        S  Deepak
# 4  35.0      0      0            373450   8.0500   NaN        S  Deepak
# 5   NaN      0      0            330877   8.4583   NaN        Q  Deepak
#
#    family
# 0       1
# 2       0
# 3       1
# 4       0
# 5       0

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      index  Survived  Pclass                                          Name  \
# 0        0         0       3                       Braund, Mr. Owen Harris
# 1        2         1       3                        Heikkinen, Miss. Laina
# 2        3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3        4         0       3                      Allen, Mr. William Henry
# 4        5         0       3                              Moran, Mr. James
# ..     ...       ...     ...                                           ...
# 885    886         0       2                         Montvila, Rev. Juozas
# 886    887         1       1                  Graham, Miss. Margaret Edith
# 887    888         0       3      Johnston, Miss. Catherine Helen "Carrie"
# 888    889         1       1                         Behr, Mr. Karl Howell
# 889    890         0       3                           Dooley, Mr. Patrick
#
# ...

# %%
# Make data frame using dictiornnay
d = {"key1":[2,3,4,5],
    "key2": [4,5,6,7,],
    "key3":[2,3,4,5]}

# %%
d
# Out:
# {'key1': [2, 3, 4, 5], 'key2': [4, 5, 6, 7], 'key3': [2, 3, 4, 5]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
d = {"key1":(2,3,4,5),
    "key2": (4,5,6,7),
    "key3":(2,3,4,5)}

# %%
d
# Out:
# {'key1': (2, 3, 4, 5), 'key2': (4, 5, 6, 7), 'key3': (2, 3, 4, 5)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
df1 = pd.read_csv("taxonomy.csv.xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   taxonomy_id  290 non-null    object
#  1   name         290 non-null    object
#  2   parent_id    279 non-null    object
#  3   parent_name  279 non-null    object
# dtypes: object(4)
# memory usage: 9.2+ KB

# %%
df1.dtypes
# Out:
# taxonomy_id    object
# name           object
# parent_id      object
# parent_name    object
# dtype: object

# %%
df1.isnull().sum()
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis = 1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1[['name']].dropna(axis = 1)
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
df1.fillna("missing_value_here>lalalala")
# Out:
#     taxonomy_id                          name                    parent_id  \
# 0           101                     Emergency  missing_value_here>lalalala
# 1        101-01             Disaster Response                          101
# 2        101-02                Emergency Cash                          101
# 3     101-02-01             Help Pay for Food                       101-02
# 4     101-02-02       Help Pay for Healthcare                       101-02
# ..          ...                           ...                          ...
# 285   111-01-07              Workplace Rights                       111-01
# 286      111-02                     Mediation                          111
# 287      111-03                        Notary                          111
# 288      111-04                Representation                          111
# 289      111-05  Translation & Interpretation                          111
#
#                      parent_name
# 0    missing_value_here>lalalala
# ...

# %%
df1.fillna("missing_value_here>lalalala", inplace = True)

# %%
df1
# Out:
#     taxonomy_id                          name                    parent_id  \
# 0           101                     Emergency  missing_value_here>lalalala
# 1        101-01             Disaster Response                          101
# 2        101-02                Emergency Cash                          101
# 3     101-02-01             Help Pay for Food                       101-02
# 4     101-02-02       Help Pay for Healthcare                       101-02
# ..          ...                           ...                          ...
# 285   111-01-07              Workplace Rights                       111-01
# 286      111-02                     Mediation                          111
# 287      111-03                        Notary                          111
# 288      111-04                Representation                          111
# 289      111-05  Translation & Interpretation                          111
#
#                      parent_name
# 0    missing_value_here>lalalala
# ...

# %%
df
# Out:
#      index  Survived  Pclass                                          Name  \
# 0        0         0       3                       Braund, Mr. Owen Harris
# 1        2         1       3                        Heikkinen, Miss. Laina
# 2        3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3        4         0       3                      Allen, Mr. William Henry
# 4        5         0       3                              Moran, Mr. James
# ..     ...       ...     ...                                           ...
# 885    886         0       2                         Montvila, Rev. Juozas
# 886    887         1       1                  Graham, Miss. Margaret Edith
# 887    888         0       3      Johnston, Miss. Catherine Helen "Carrie"
# 888    889         1       1                         Behr, Mr. Karl Howell
# 889    890         0       3                           Dooley, Mr. Patrick
#
# ...

# %%
# what is the avg fare paid by people who survive?

# %%
# groupby (https://www.w3resource.com/python-exercises/pandas/groupby/index.php)

# %%
df.groupby('Survived').mean()
# Out:
# /tmp/ipykernel_111/1397368861.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#                index    Pclass        Age     SibSp     Parch       Fare  \
# Survived
# 0         446.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1         444.665689  1.953079  28.310277  0.472141  0.466276  48.328288
#
#             family
# Survived
# 0         0.883424
# 1         0.938416

# %%
df.groupby('Survived').max()
# Out:
# /tmp/ipykernel_111/123491824.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby('Survived').max()
#           index  Pclass                         Name   Sex   Age  SibSp  \
# Survived
# 0           890       3  van Melkebeke, Mr. Philemon  male  74.0      8
# 1           889       3      de Mulder, Mr. Theodore  male  80.0      4
#
#           Parch     Ticket      Fare new_col  family
# Survived
# 0             6  WE/P 5735  263.0000  Deepak      10
# 1             5  WE/P 5735  512.3292  Deepak       6

# %%
df.groupby('Survived').min()
# Out:
# /tmp/ipykernel_111/2003144291.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df.groupby('Survived').min()
#           index  Pclass                              Name     Sex   Age  \
# Survived
# 0             0       1               Abbing, Mr. Anthony  female  1.00
# 1             2       1  Abbott, Mrs. Stanton (Rosa Hunt)  female  0.42
#
#           SibSp  Parch  Ticket  Fare new_col  family
# Survived
# 0             0      0  110413   0.0  Deepak       0
# 1             0      0  110152   0.0  Deepak       0

# %%
df.groupby('Survived').sum()
# Out:
# /tmp/ipykernel_111/351563020.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').sum()
#            index  Pclass       Age  SibSp  Parch        Fare  family
# Survived
# 0         244863    1390  12985.50    304    181  12142.7199     485
# 1         151631     666   8181.67    161    159  16479.9461     320

# %%
df.groupby('Survived').describe()
# Out:
#           index                                                           \
#           count        mean         std  min    25%    50%    75%    max
# Survived
# 0         549.0  446.016393  260.640469  0.0  210.0  454.0  674.0  890.0
# 1         341.0  444.665689  251.585069  2.0  255.0  440.0  651.0  889.0
#
#          Pclass            ...  Fare           family                      \
#           count      mean  ...   75%       max  count      mean       std
# Survived                   ...
# 0         549.0  2.531876  ...  26.0  263.0000  549.0  0.883424  1.830669
# 1         341.0  1.953079  ...  57.0  512.3292  341.0  0.938416  1.187814
#
#
#           min  25%  50%  75%   max
# Survived
# 0         0.0  0.0  0.0  1.0  10.0
# 1         0.0  0.0  1.0  2.0   6.0
#
# [2 rows x 56 columns]

# %%
df.groupby('Survived').aggregate([min,'max', 'mean','median','count',np.std,'var'])
# Out:
# /tmp/ipykernel_111/2847341773.py:1: FutureWarning: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked', 'new_col'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('Survived').aggregate([min,'max', 'mean','median','count',np.std,'var'])
#          index                                                         Pclass  \
#            min  max        mean median count         std           var    min
# Survived
# 0            0  890  446.016393  454.0   549  260.640469  67933.454110      1
# 1            2  889  444.665689  440.0   341  251.585069  63295.046731      1
#
#                         ...  Fare                         family      \
#          max      mean  ... count        std          var    min max
# Survived                ...
# 0          3  2.531876  ...   549  31.388207   985.219509      0  10
# 1          3  1.953079  ...   341  66.683277  4446.659477      0   6
# ...

# %%
# groupby with two columns
# Q. Avg people who survived for each sex, pclass

# %%
df.groupby(['Sex','Pclass'])['Survived'].sum()
# Out:
# Sex     Pclass
# female  1         90
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
df
# Out:
#      index  Survived  Pclass                                          Name  \
# 0        0         0       3                       Braund, Mr. Owen Harris
# 1        2         1       3                        Heikkinen, Miss. Laina
# 2        3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3        4         0       3                      Allen, Mr. William Henry
# 4        5         0       3                              Moran, Mr. James
# ..     ...       ...     ...                                           ...
# 885    886         0       2                         Montvila, Rev. Juozas
# 886    887         1       1                  Graham, Miss. Margaret Edith
# 887    888         0       3      Johnston, Miss. Catherine Helen "Carrie"
# 888    889         1       1                         Behr, Mr. Karl Howell
# 889    890         0       3                           Dooley, Mr. Patrick
#
# ...

# %%
df1 = df.groupby('Pclass').sum(numeric_only = True)

# %%
df1
# Out:
#          index  Survived      Age  SibSp  Parch        Fare  family
# Pclass
# 1        99488       135  7073.42     89     77  18106.1292     166
# 2        81872        87  5168.83     74     70   3801.8417     144
# 3       215134       119  8924.92    302    193   6714.6951     495

# %%
df1.T
# Out:
# Pclass             1           2            3
# index     99488.0000  81872.0000  215134.0000
# Survived    135.0000     87.0000     119.0000
# Age        7073.4200   5168.8300    8924.9200
# SibSp        89.0000     74.0000     302.0000
# Parch        77.0000     70.0000     193.0000
# Fare      18106.1292   3801.8417    6714.6951
# family      166.0000    144.0000     495.0000

# %%
pd.__version__
# Out:
# '1.5.2'

# %%
df1.transpose()
# Out:
# Pclass             1           2            3
# index     99488.0000  81872.0000  215134.0000
# Survived    135.0000     87.0000     119.0000
# Age        7073.4200   5168.8300    8924.9200
# SibSp        89.0000     74.0000     302.0000
# Parch        77.0000     70.0000     193.0000
# Fare      18106.1292   3801.8417    6714.6951
# family      166.0000    144.0000     495.0000

# %%
### 
df.head()
# Out:
#    index  Survived  Pclass                                          Name  \
# 0      0         0       3                       Braund, Mr. Owen Harris
# 1      2         1       3                        Heikkinen, Miss. Laina
# 2      3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3      4         0       3                      Allen, Mr. William Henry
# 4      5         0       3                              Moran, Mr. James
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 2  female  35.0      1      0            113803  53.1000  C123        S
# 3    male  35.0      0      0            373450   8.0500   NaN        S
# 4    male   NaN      0      0            330877   8.4583   NaN        Q
#
#   new_col  family
# 0  Deepak       1
# 1  Deepak       0
# 2  Deepak       1
# ...

# %%
df.drop('index', axis = 1, inplace = True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 885         0       2                         Montvila, Rev. Juozas    male
# 886         1       1                  Graham, Miss. Margaret Edith  female
# 887         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 888         1       1                         Behr, Mr. Karl Howell    male
# 889         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df_1 = df[['Name','Sex','Age']]

# %%
df_1
# Out:
#                                              Name     Sex   Age
# 0                         Braund, Mr. Owen Harris    male  22.0
# 1                          Heikkinen, Miss. Laina  female  26.0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3                        Allen, Mr. William Henry    male  35.0
# 4                                Moran, Mr. James    male   NaN
# ..                                            ...     ...   ...
# 885                         Montvila, Rev. Juozas    male  27.0
# 886                  Graham, Miss. Margaret Edith  female  19.0
# 887      Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 888                         Behr, Mr. Karl Howell    male  26.0
# 889                           Dooley, Mr. Patrick    male  32.0
#
# [890 rows x 3 columns]

# %%
df_1 = df[['Name','Sex','Age']][0:5]

# %%
df_1
# Out:
#                                            Name     Sex   Age
# 0                       Braund, Mr. Owen Harris    male  22.0
# 1                        Heikkinen, Miss. Laina  female  26.0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3                      Allen, Mr. William Henry    male  35.0
# 4                              Moran, Mr. James    male   NaN

# %%
df_2 = df[['Name','Sex','Age']][5:10]

# %%
df_2.reset_index(drop = True, inplace = True)

# %%
result = pd.concat([df_1, df_2], axis = 0)

# %%
result
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1                             Heikkinen, Miss. Laina  female  26.0
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3                           Allen, Mr. William Henry    male  35.0
# 4                                   Moran, Mr. James    male   NaN
# 0                            McCarthy, Mr. Timothy J    male  54.0
# 1                     Palsson, Master. Gosta Leonard    male   2.0
# 2  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 3                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 4                    Sandstrom, Miss. Marguerite Rut  female   4.0

# %%
pd.concat([df_1, df_2], axis = 1)
# Out:
#                                            Name     Sex   Age  \
# 0                       Braund, Mr. Owen Harris    male  22.0
# 1                        Heikkinen, Miss. Laina  female  26.0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3                      Allen, Mr. William Henry    male  35.0
# 4                              Moran, Mr. James    male   NaN
#
#                                                 Name     Sex   Age
# 0                            McCarthy, Mr. Timothy J    male  54.0
# 1                     Palsson, Master. Gosta Leonard    male   2.0
# 2  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 3                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 4                    Sandstrom, Miss. Marguerite Rut  female   4.0

# %%
## merge and  join operation

# %%
df1 = pd.DataFrame({'key1' : [1,2,4,5,6],
                    'key2' : [4,5,6,7,8],
                    'key3' : [3,4,5,6,6]
})

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2 = pd.DataFrame({'key1' : [1,2,45,6,67],
                    'key4' : [56,5,6,7,8],
                    'key5' : [3,56,5,6,6]
})

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
# merge and join


pd.merge(df1,df2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    56     3
# 1     2     5     4     5    56
# 2     6     8     6     7     6

# %%
pd.merge(df1,df2, how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  56.0   3.0
# 1     2     5     4   5.0  56.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6   7.0   6.0

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2, how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    56     3
# 1     2   5.0   4.0     5    56
# 2    45   NaN   NaN     6     5
# 3     6   8.0   6.0     7     6
# 4    67   NaN   NaN     8     6

# %%
pd.merge(df1, df2, how = 'outer') # all the keys of both the dataframe
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  56.0   3.0
# 1     2   5.0   4.0   5.0  56.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0   7.0   6.0
# 5    45   NaN   NaN   6.0   5.0
# 6    67   NaN   NaN   8.0   6.0

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1, df2, how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    56     3
# 1        1     4     3       2     5    56
# 2        1     4     3      45     6     5
# 3        1     4     3       6     7     6
# 4        1     4     3      67     8     6
# 5        2     5     4       1    56     3
# 6        2     5     4       2     5    56
# 7        2     5     4      45     6     5
# 8        2     5     4       6     7     6
# 9        2     5     4      67     8     6
# 10       4     6     5       1    56     3
# 11       4     6     5       2     5    56
# 12       4     6     5      45     6     5
# 13       4     6     5       6     7     6
# 14       4     6     5      67     8     6
# 15       5     7     6       1    56     3
# 16       5     7     6       2     5    56
# 17       5     7     6      45     6     5
# 18       5     7     6       6     7     6
# 19       5     7     6      67     8     6
# 20       6     8     6       1    56     3
# ...

# %%
df1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df2
# Out:
#    key1  key4  key5
# 0     1    56     3
# 1     2     5    56
# 2    45     6     5
# 3     6     7     6
# 4    67     8     6

# %%
pd.merge(df1,df2, how = 'left', left_on = 'key2', right_on = 'key4')
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     4     3     NaN   NaN   NaN
# 1       2     5     4     2.0   5.0  56.0
# 2       4     6     5    45.0   6.0   5.0
# 3       5     7     6     6.0   7.0   6.0
# 4       6     8     6    67.0   8.0   6.0

# %%
# join

# %%
df1 = pd.DataFrame({'key1' : [1,2,4,5,6],
                    'key2' : [4,5,6,7,8],
                    'key3' : [3,4,5,6,6],
                    
},
index = ['a','b','c','d','e']
)

# %%
df2 = pd.DataFrame({'key6' : [1,2,45,6,67],
                    'key4' : [56,5,6,7,8],
                    'key5' : [3,56,5,6,6],
                    
},
index = ['a','b','h','i','j']
)

# %%
df2
# Out:
#    key6  key4  key5
# a     1    56     3
# b     2     5    56
# h    45     6     5
# i     6     7     6
# j    67     8     6

# %%
df1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
df1.join(df2, how = 'left') # join happens on the indexes, column name should be not common"
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3   1.0  56.0   3.0
# b     2     5     4   2.0   5.0  56.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
df1.join(df2, how = 'right')
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0     1    56     3
# b   2.0   5.0   4.0     2     5    56
# h   NaN   NaN   NaN    45     6     5
# i   NaN   NaN   NaN     6     7     6
# j   NaN   NaN   NaN    67     8     6

# %%
df1.join(df2, how = 'outer')
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0   1.0  56.0   3.0
# b   2.0   5.0   4.0   2.0   5.0  56.0
# c   4.0   6.0   5.0   NaN   NaN   NaN
# d   5.0   7.0   6.0   NaN   NaN   NaN
# e   6.0   8.0   6.0   NaN   NaN   NaN
# h   NaN   NaN   NaN  45.0   6.0   5.0
# i   NaN   NaN   NaN   6.0   7.0   6.0
# j   NaN   NaN   NaN  67.0   8.0   6.0

# %%
df1.join(df2, how = 'cross')
# Out:
#     key1  key2  key3  key6  key4  key5
# 0      1     4     3     1    56     3
# 1      1     4     3     2     5    56
# 2      1     4     3    45     6     5
# 3      1     4     3     6     7     6
# 4      1     4     3    67     8     6
# 5      2     5     4     1    56     3
# 6      2     5     4     2     5    56
# 7      2     5     4    45     6     5
# 8      2     5     4     6     7     6
# 9      2     5     4    67     8     6
# 10     4     6     5     1    56     3
# 11     4     6     5     2     5    56
# 12     4     6     5    45     6     5
# 13     4     6     5     6     7     6
# 14     4     6     5    67     8     6
# 15     5     7     6     1    56     3
# 16     5     7     6     2     5    56
# 17     5     7     6    45     6     5
# 18     5     7     6     6     7     6
# 19     5     7     6    67     8     6
# 20     6     8     6     1    56     3
# 21     6     8     6     2     5    56
# 22     6     8     6    45     6     5
# ...

# %%
df1.join(df2, how = 'inner')
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3     1    56     3
# b     2     5     4     2     5    56

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 885         0       2                         Montvila, Rev. Juozas    male
# 886         1       1                  Graham, Miss. Margaret Edith  female
# 887         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 888         1       1                         Behr, Mr. Karl Howell    male
# 889         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.Fare
# Out:
# 0       7.2500
# 1       7.9250
# 2      53.1000
# 3       8.0500
# 4       8.4583
#         ...
# 885    13.0000
# 886    30.0000
# 887    23.4500
# 888    30.0000
# 889     7.7500
# Name: Fare, Length: 890, dtype: float64

# %%
df['Fare_inr'] = df['Fare'].apply(lambda x: x*90)

# %%
df['Fare_inr']
# Out:
# 0       652.500
# 1       713.250
# 2      4779.000
# 3       724.500
# 4       761.247
#          ...
# 885    1170.000
# 886    2700.000
# 887    2110.500
# 888    2700.000
# 889     697.500
# Name: Fare_inr, Length: 890, dtype: float64

# %%
df['Fare_inr'] = df['Fare'] * 100

# %%
df['Fare_inr']
# Out:
# 0       725.00
# 1       792.50
# 2      5310.00
# 3       805.00
# 4       845.83
#         ...
# 885    1300.00
# 886    3000.00
# 887    2345.00
# 888    3000.00
# 889     775.00
# Name: Fare_inr, Length: 890, dtype: float64

# %%
df['Name']
# Out:
# 0                           Braund, Mr. Owen Harris
# 1                            Heikkinen, Miss. Laina
# 2      Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 3                          Allen, Mr. William Henry
# 4                                  Moran, Mr. James
#                            ...
# 885                           Montvila, Rev. Juozas
# 886                    Graham, Miss. Margaret Edith
# 887        Johnston, Miss. Catherine Helen "Carrie"
# 888                           Behr, Mr. Karl Howell
# 889                             Dooley, Mr. Patrick
# Name: Name, Length: 890, dtype: object

# %%
len('Braund, Mr. Owen Harris')
# Out:
# 23

# %%
df['len_name'] = df['Name'].apply(len)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 885         0       2                         Montvila, Rev. Juozas    male
# 886         1       1                  Graham, Miss. Margaret Edith  female
# 887         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 888         1       1                         Behr, Mr. Karl Howell    male
# 889         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
def convert(x):
    return x * 90

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 885         0       2                         Montvila, Rev. Juozas    male
# 886         1       1                  Graham, Miss. Margaret Edith  female
# 887         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 888         1       1                         Behr, Mr. Karl Howell    male
# 889         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df['Fare']
# Out:
# 0       7.2500
# 1       7.9250
# 2      53.1000
# 3       8.0500
# 4       8.4583
#         ...
# 885    13.0000
# 886    30.0000
# 887    23.4500
# 888    30.0000
# 889     7.7500
# Name: Fare, Length: 890, dtype: float64

# %%
def create_flag(x):
    if x < 10:
        return "cheap"
    elif x >= 10 and x < 20:
        return "medium"
    else:
        return "High"

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 885         0       2                         Montvila, Rev. Juozas    male
# 886         1       1                  Graham, Miss. Margaret Edith  female
# 887         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 888         1       1                         Behr, Mr. Karl Howell    male
# 889         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
data = {"a": [1,2,3,4],
        "b": [5,5,6,7],
        "c": ["pw", "skills", "aj","cj"]}

df1 = pd.DataFrame(data)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 1           1       3                        Heikkinen, Miss. Laina  female
# 2           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3           0       3                      Allen, Mr. William Henry    male
# 4           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 885         0       2                         Montvila, Rev. Juozas    male
# 886         1       1                  Graham, Miss. Margaret Edith  female
# 887         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 888         1       1                         Behr, Mr. Karl Howell    male
# 889         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df1.set_index('c', inplace = True)

# %%
df1.reset_index(drop = True)
# Out:
#    a  b
# 0  1  5
# 1  2  5
# 2  3  6
# 3  4  7

# %%
df1.reindex(['a','f','g','h'])
# Out:
#     a   b
# c
# a NaN NaN
# f NaN NaN
# g NaN NaN
# h NaN NaN

# %%
data = {"a": [1,2,3,4],
        "b": [5,5,6,7],
        "c": ["pw", "skills", "aj","cj"]}
df1 = pd.DataFrame(data)

# %%
df1
# Out:
#    a  b       c
# 0  1  5      pw
# 1  2  5  skills
# 2  3  6      aj
# 3  4  7      cj

# %%
for i in df1.iterrows():   #row wise
    print(i, "-----------")
# Out:
# (0, a     1
# b     5
# c    pw
# Name: 0, dtype: object) -----------
# (1, a         2
# b         5
# c    skills
# Name: 1, dtype: object) -----------
# (2, a     3
# b     6
# c    aj
# Name: 2, dtype: object) -----------
# (3, a     4
# b     7
# c    cj
# Name: 3, dtype: object) -----------

# %%
for i in df1.iteritems():   #colums wise
    print(i)
# Out:
# ('a', 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64)
# ('b', 0    5
# 1    5
# 2    6
# 3    7
# Name: b, dtype: int64)
# ('c', 0        pw
# 1    skills
# 2        aj
# 3        cj
# Name: c, dtype: object)
# /tmp/ipykernel_111/3986969135.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for i in df1.iteritems():   #colums wise

# %%
def func_sum(x):
    return x.sum()

# %%
df1['sum1'] = df.apply(func_sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 df1['sum1'] = df.apply(func_sum)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:9565, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/apply.py:873, in FrameApply.apply_standard(self)
#     872 def apply_standard(self):
# ...

# %%
df1

# %%
df2 = df1[["a","b"]]

# %%
df2

# %%
df2.apply(func_sum, axis = 0)

# %%
df2.apply(func_sum, axis = 1)

# %%
df2.applymap(lambda x: x ** 2)

# %%
df2

# %%
df2 ** 2

# %%
df1

# %%
df1.sort_values(by = 'c')

# %%
df1.sort_index()

# %%
df

# %%
df3 = pd.DataFrame({"desc" : ["Data science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processes, algorithms and systems to extract or extrapolate knowledge and insights from potentially noisy, structured, or unstructured data.[2]Data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]Data science is a  with data.[5] It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.[6] However, data science is different from computer science and information science. Turing Award winner Jim Gray imagined data science as aof science (empirical, theoretical, computational, and now data-driven) and asand the data deluge.[7][8]A data scientist is a professional who creates programming code and combines it with statistical knowledge to create insights from data.[9]FoundationsData science is an interdisciplinary field[10] focused on extracting knowledge from typically large data sets and applying the knowledge and insights from that data to solve problems in a wide range of application domains. The field encompasses preparing data for analysis, formulating data science problems, analyzing data, developing data-driven solutions, and presenting findings to inform high-level decisions in a broad range of application domains. As such, it incorporates skills from computer science, statistics, information science, mathematics, data visualization, information visualization, data sonification, data integration, graphic design, complex systems, communication and business.[11][12] Statistician Nathan Yau, drawing on Ben Fry, also links data science to human–computer interaction: users should be able to intuitively control and explore data.[13][14] In 2015, the American Statistical Association identified database management, statistics and machine learning, and distributed and parallel systems as the three emerging foundational professional communities.15"]})

# %%
df3

# %%
pd.set_option("display.max_colwidth", 1000)

# %%
df3

# %%
df1

# %%
pd.set_option("display.max_rows", 500)
pd.set_option("display.max_columns", 500)

# %%
df[:500]

# %%
df3['char_len'] = df3['desc'].apply(len)

# %%
df3

# %%
a = "I am Deepak learnig Data Science"
len(a)

# %%
a.split()

# %%
len(a.split())

# %%
df3['word_count'] = df3['desc'].apply(lambda x: ())

# %%
df3

# %%
df2

# %%
df2

# %%
df2['a'].mean()

# %%
df2['a'].median()

# %%
df2['a'].min()

# %%
df2['a'].var()

# %%
df2['a'].describe()

# %%
df4 = pd.DataFrame({'a':[1,2,3,4,5,6,7,8,9]})

# %%
df4

# %%
df4.mean()

# %%
df4['b']=df4.rolling(window = 1).mean()

# %%
df4['a'] = df4['a'].astype(int)

# %%
df4

# %%
df4

# %%
df4.drop(0, axis = 0, inplace = True)

# %%
df4

# %%
df4.rolling(window = 2).sum()

# %%
df4.rolling(window = 2).mean()

# %%
df4

# %%
df4.cumsum()

# %%
# data time
df = pd.DataFrame({"data":['2024-02-08', '2024-02-09','2024-02-10']})

# %%
df

# %%
df.dtypes

# %%
df['updated_data'] = pd.to_datetime(df['data'])

# %%
df

# %%
df.dtypes

# %%
df

# %%
df

# %%
###### pandas time delta

time = pd.Timedelta(days = 1, hours = 6, minutes = 50 )

# %%
time

# %%
dt = pd.to_datetime('2024-02-08')

# %%
dt

# %%
dt + time

# %%
d = pd.Series([1,2,3,8,5,6])

# %%
d

# %%
d.plot()
